# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.options.display.float_format = '{:.3f}'.format
# pd.reset_option('^display.', silent=True)
plt.style.use('default')

# %%
data = pd.read_csv('out.csv')

# %%
data['Date'] = [ x[:-9] for x in data['Date'] ]
data['Date'] = pd.to_datetime(data['Date'])
data[['Top 5% ownership','Top 10% ownership','Top 25% ownership','Top 50% ownership']] = data[
    ['Top 5% ownership','Top 10% ownership','Top 25% ownership','Top 50% ownership']].multiply(100, axis='index')

# %%
data.drop_duplicates(['Date'], keep="last", inplace=True)

# %%
data.sort_values(by=['Date'], inplace=True)

# %%
data.set_index('Date', inplace=True)

# %%
data.head()
# Out:
#             Shift    Total  Accounts  Max balance  \
# Date
# 2020-11-03      0  1326448       141       118408
# 2020-11-04      0  1440845       143       123908
# 2020-11-06      0  1501906       168       123908
# 2020-11-07      0  1516564       192       123908
# 2020-11-08      0  2087686       209       143508
#
#                                                       Richest  Top 5% wealth  \
# Date
# 2020-11-03  a2d73cf3b37a62276ade44a96860495510d0e7d7c46895...         684395
# 2020-11-04  a2d73cf3b37a62276ade44a96860495510d0e7d7c46895...         694898
# 2020-11-06  a2d73cf3b37a62276ade44a96860495510d0e7d7c46895...         776095
# 2020-11-07  a2d73cf3b37a62276ade44a96860495510d0e7d7c46895...         905949
# 2020-11-08  a2d73cf3b37a62276ade44a96860495510d0e7d7c46895...        1062463
#
#             Top 5% ownership  Top 5% accounts  Top 10% wealth  \
# Date
# 2020-11-03            51.596                7          957965
# 2020-11-04            48.229                7         1042663
# 2020-11-06            51.674                8         1129562
# 2020-11-07            59.737               10         1175470
# 2020-11-08            50.892               10         1513839
#
#             Top 10% ownership  Top 10% accounts  Top 25% wealth  \
# Date
# 2020-11-03             72.220                14         1237242
# 2020-11-04             72.365                14         1354769
# 2020-11-06             75.209                17         1423386
# 2020-11-07             77.509                19         1435981
# 2020-11-08             72.513                21         1991775
#
#             Top 25% ownership  Top 25% accounts  Top 50% wealth  \
# Date
# 2020-11-03             93.275                35         1291831
# 2020-11-04             94.026                36         1407558
# 2020-11-06             94.772                42         1470073
# 2020-11-07             94.686                48         1483981
# 2020-11-08             95.406                52         2051962
#
#             Top 50% ownership  Top 50% accounts
# Date
# 2020-11-03             97.390                71
# 2020-11-04             97.690                72
# 2020-11-06             97.880                84
# 2020-11-07             97.852                96
# 2020-11-08             98.289               105

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23 entries, 2020-11-03 to 2020-12-03
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Shift              23 non-null     int64
#  1   Total              23 non-null     int64
#  2   Accounts           23 non-null     int64
#  3   Max balance        23 non-null     int64
#  4   Richest            23 non-null     object
#  5   Top 5% wealth      23 non-null     int64
#  6   Top 5% ownership   23 non-null     float64
#  7   Top 5% accounts    23 non-null     int64
#  8   Top 10% wealth     23 non-null     int64
#  9   Top 10% ownership  23 non-null     float64
#  10  Top 10% accounts   23 non-null     int64
#  11  Top 25% wealth     23 non-null     int64
#  12  Top 25% ownership  23 non-null     float64
#  13  Top 25% accounts   23 non-null     int64
#  14  Top 50% wealth     23 non-null     int64
#  15  Top 50% ownership  23 non-null     float64
#  16  Top 50% accounts   23 non-null     int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 3.2+ KB

# %%
data.describe()
# Out:
#        Shift       Total  Accounts  Max balance  Top 5% wealth  \
# count 23.000      23.000    23.000       23.000         23.000
# mean   0.000 3106417.609   287.130   160490.348    1531870.783
# std    0.000 1347259.405    73.488    28292.257     538847.265
# min    0.000 1326448.000   141.000   118408.000     684395.000
# 25%    0.000 2168698.000   240.000   143461.000    1173777.000
# 50%    0.000 3073910.000   307.000   163066.000    1554712.000
# 75%    0.000 4341530.000   346.500   182666.000    1988673.000
# max    0.000 5649512.000   368.000   213942.000    2445774.000
#
#        Top 5% ownership  Top 5% accounts  Top 10% wealth  Top 10% ownership  \
# count            23.000           23.000          23.000             23.000
# mean             50.916           14.348     2228305.652             72.761
# std               4.901            3.725      883256.917              3.096
# min              43.291            7.000      957965.000             67.633
# 25%              46.554           12.000     1601687.500             70.199
# 50%              51.303           15.000     2247850.000             72.513
# 75%              54.103           17.000     3024041.000             75.296
# max              59.737           18.000     3820963.000             77.649
#
#        Top 10% accounts  Top 25% wealth  Top 25% ownership  Top 25% accounts  \
# count            23.000          23.000             23.000            23.000
# mean             28.696     2983082.739             95.683            71.826
# std               7.400     1315946.242              0.931            18.404
# min              14.000     1237242.000             93.275            35.000
# 25%              24.000     2068713.500             95.206            60.000
# 50%              31.000     2952269.000             96.043            77.000
# 75%              34.500     4193872.500             96.496            86.500
# max              37.000     5463749.000             96.712            92.000
#
#        Top 50% wealth  Top 50% ownership  Top 50% accounts
# count          23.000             23.000            23.000
# mean      3066247.522             98.525           143.826
# std       1341310.672              0.481            36.705
# min       1291831.000             97.390            71.000
# 25%       2133149.500             98.292           120.500
# 50%       3033062.000             98.671           154.000
# 75%       4296664.000             98.967           173.500
# max       5595214.000             99.048           184.000

# %%
fig, axes = plt.subplots(2,1)
fig.tight_layout(h_pad=2)
axes[0].set_title('Total coins distributed over time') 
axes[0].ticklabel_format(style='plain')
axes[0].set_ylabel('Coins')
axes[1].set_title('Total backup accounts over time')
axes[1].set_ylabel('Accounts')
data['Total'].plot(ax=axes[0], figsize=(12,12), style='.-')
data['Accounts'].plot(ax=axes[1], figsize=(12,12), style='.-')

# %%
data['Shift'] = data['Total'] - data['Total'].shift(1)

# %%
fig, ax = plt.subplots()
data['Shift'].plot(ax=ax, figsize=(14,6), style='.-')
ax.set_title('Daily change in coins')
ax.set_ylabel('Coins')
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
ax = data[['Top 5% ownership','Top 10% ownership','Top 25% ownership','Top 50% ownership']].plot(
    kind='line', figsize=(12,6), style='.-', grid=True)
ax.set_ylim([0,100])
ax.set_ylabel('Ownership in %')
ax.set_title('Ownership of different groups')
# Out:
# Text(0.5, 1.0, 'Ownership of different groups')

# %%
latest_wealth = data[['Top 5% wealth','Total','Top 10% wealth','Top 25% wealth','Top 50% wealth']].iloc[-1]
latest_wealth['Total'] = latest_wealth['Total'] - latest_wealth['Top 50% wealth'] 
latest_wealth['Top 50% wealth'] = latest_wealth['Top 50% wealth'] - latest_wealth['Top 25% wealth']
latest_wealth['Top 25% wealth'] = latest_wealth['Top 25% wealth'] - latest_wealth['Top 10% wealth']
latest_wealth['Top 10% wealth'] = latest_wealth['Top 10% wealth'] - latest_wealth['Top 5% wealth']

latest_wealth.rename({
    'Top 5% wealth': 'Top 5% wealth',
    'Total': 'Rest 50-100% of the network',
    'Top 10% wealth': 'Top 5-10% wealth',
    'Top 25% wealth': 'Top 10-25% wealth',
    'Top 50% wealth': 'Top 25-50% wealth'
}, inplace=True)

ax = latest_wealth.plot(kind='pie', autopct='%1.1f%%', pctdistance=0.65, wedgeprops=dict(width=0.7), explode=[0.1] * 5, startangle=90)
ax.yaxis.set_label_coords(1.4,0.5)
ax.set_title('Percentage of wealth held');

# %%
# Figure Size 
fig, ax = plt.subplots(figsize =(8, 4)) 
  
name = ['Top 5% ownership','Top 10% ownership','Top 25% ownership','Top 50% ownership']
percent = data[['Top 5% ownership','Top 10% ownership','Top 25% ownership','Top 50% ownership']].iloc[-1].values
    
# Horizontal Bar Plot 
ax.barh(name, percent, color=['b', 'r', 'g', 'y', 'k'])
  
# Remove axes splines 
for s in ['top', 'bottom', 'left', 'right']: 
    ax.spines[s].set_visible(False) 
  
# Remove x, y Ticks 
ax.xaxis.set_ticks_position('none') 
ax.yaxis.set_ticks_position('none')
ax.set_xlabel('Ownership percentage')
  
# Add x, y gridlines 
ax.grid(b = True, color ='grey', 
        linestyle ='-.', linewidth = 0.5, 
        alpha = 0.5) 
  
# Show top values  
ax.invert_yaxis() 
  
# Add annotation to bars 
for i in ax.patches: 
    plt.text(i.get_width()+0.2, i.get_y()+0.5,  
             str(round((i.get_width()), 2)), 
             fontsize = 12, fontweight ='bold', 
             color ='grey') 
  
# Add Plot Title 
ax.set_title('Wealth distribution on 2020-12-03 in %');
